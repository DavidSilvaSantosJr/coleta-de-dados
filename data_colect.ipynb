# %%
from bs4 import BeautifulSoup
import requests

url = "https://www.residentevildatabase.com/personagens/ada-wong/"

# %%
# usar headear é uma boa prática!
headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'accept-language': 'en-US,en;q=0.9,pt-BR;q=0.8,pt;q=0.7',
    'cache-control': 'max-age=0',
    'cookie': '_gid=GA1.2.92603084.1722632737; __gads=ID=3a1ac9eb250d78a1:T=1722632740:RT=1722632740:S=ALNI_MbrsALGAEWZF_Bm-Qh7ZhuEzI0oFg; __gpi=UID=00000a4b0024a22e:T=1722632740:RT=1722632740:S=ALNI_MYxN8vbhZl0FirufS77rIa1mP6sVg; __eoi=ID=71fe29e35a59a522:T=1722632740:RT=1722632740:S=AA-AfjaL602qh4jPDbNdxhI5q0-8; _gat_gtag_UA_29446588_1=1; _ga=GA1.2.889671048.1722632737; FCNEC=%5B%5B%22AKsRol_8J8DRpmOZD2DdhBgvYArBP1rEs0G0OSMQ_IXizWkVauG-VkeyoOg4Xmr25vT_1dFao-eiYIaoDB8jF5Up0qjhdvNA7Kfa6r6n7o4FY95sIAHXe4KWBq2H9u3z3OdNbXW5q-ENY1FMjdX4ClaV-mrBovqJYA%3D%3D%22%5D%5D; _ga_DJLCSW50SC=GS1.1.1722632736.1.1.1722632874.56.0.0; _ga_D6NF5QC4QT=GS1.1.1722632736.1.1.1722632874.56.0.0',
    'priority': 'u=0, i',
    'referer': 'https://www.residentevildatabase.com/personagens/',
    'sec-ch-ua': '"Not)A;Brand";v="99", "Google Chrome";v="127", "Chromium";v="127"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36',
}

# %%
resp = requests.get(url, headers=headers) # captrura o url

# print(resp.status_code)
#print(resp.text)

soup = BeautifulSoup(resp.text) #captura e estrutura o html da pagina
soup
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]>    <html class="ie8" lang="en"> <![endif]--><!--[if IE 9]>    <html class="ie9" lang="en"> <![endif]--><!--[if gt IE 8]><!--><html lang="pt-BR"> <!--<![endif]-->
# <head>
# <title>Ada Wong | Resident Evil Database</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://www.residentevildatabase.com/xmlrpc.php" rel="pingback"/>
# <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>
# <link href="https://www.residentevildatabase.com/wp-content/uploads/2018/05/redb-favicon.png" rel="icon" type="image/png"/><!-- Google tag (gtag.js) Consent Mode dataLayer added by Site Kit -->
# <script id="google_gtagjs-js-consent-mode-data-layer">
# window.dataLayer = window.dataLayer || [];function gtag(){dataLayer.push(arguments);}
# ...

# %%
#busca a div que possui classes específicas
div_page = soup.find("div",  class_="td-page-content")
div_page

# %%
# busca as tags especificadas da div
# [1] -> 2° p encontrado na div
paragrafo = div_page.find_all("p")[1]

# %%
em =paragrafo.findAll("em")
em
# Out:
# [<em>Ano de nascimento: 1974 (24 anos em 1998)</em>,
#  <em> Tipo sanguíneo: AB</em>,
#  <em> Altura: Desconhecida.</em>,
#  <em> Peso: Desconhecido.</em>]

# %%
#busca o texto(string) de em(tag)
em[-1].text
em[1].text[2:5]
# Out:
# 'ipo'

# %%
#inserindo texto num dicionario
data = {}
for i in em:
    k, v = i.text.split(":")
    k = k.strip(" ")
    data[k] = v.strip(" ")

data
# Out:
# {'Ano de nascimento': '1974 (24 anos em 1998)',
#  'Tipo sanguíneo': 'AB',
#  'Altura': 'Desconhecida.',
#  'Peso': 'Desconhecido.'}

# %%
data['Ano de nascimento']
# Out:
# '1974 (24 anos em 1998)'
